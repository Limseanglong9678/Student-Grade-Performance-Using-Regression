# %%
import pandas as pd

# %%
df = pd.read_csv('StudentPerformanceFactors_Cleaned.csv')
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6372             25          69                 High              Medium
# 6373             23          76                 High              Medium
# 6374             20          90               Medium                 Low
# 6375             10          86                 High                High
# 6376             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                            No            7               73
# 1                            No            8               59
# 2                           Yes            7               91
# 3                           Yes            8               98
# 4                           Yes            6               65
# ...                         ...          ...              ...
# 6372                         No            7               76
# 6373                         No            8               81
# 6374                        Yes            6               65
# 6375                        Yes            6               91
# 6376                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 0                 Low             Yes                  0           Low
# 1                 Low             Yes                  2        Medium
# 2              Medium             Yes                  2        Medium
# 3              Medium             Yes                  1        Medium
# 4              Medium             Yes                  3        Medium
# ...               ...             ...                ...           ...
# 6372           Medium             Yes                  1          High
# 6373           Medium             Yes                  3           Low
# 6374              Low             Yes                  3           Low
# 6375             High             Yes                  2           Low
# 6376           Medium             Yes                  0        Medium
#
#      Teacher_Quality School_Type Peer_Influence  Physical_Activity  \
# 0             Medium      Public       Positive                  3
# 1             Medium      Public       Negative                  4
# 2             Medium      Public        Neutral                  4
# 3             Medium      Public       Negative                  4
# 4               High      Public        Neutral                  4
# ...              ...         ...            ...                ...
# 6372          Medium      Public       Positive                  2
# 6373            High      Public       Positive                  2
# 6374          Medium      Public       Negative                  2
# 6375          Medium     Private       Positive                  3
# 6376          Medium      Public       Positive                  4
#
#      Learning_Disabilities Parental_Education_Level Distance_from_Home  \
# 0                       No              High School               Near
# 1                       No                  College           Moderate
# 2                       No             Postgraduate               Near
# 3                       No              High School           Moderate
# 4                       No                  College               Near
# ...                    ...                      ...                ...
# 6372                    No              High School               Near
# 6373                    No              High School               Near
# 6374                    No             Postgraduate               Near
# 6375                    No              High School                Far
# 6376                    No             Postgraduate               Near
#
#       Gender  Exam_Score
# 0       Male          67
# 1     Female          61
# 2       Male          74
# 3       Male          71
# 4     Female          70
# ...      ...         ...
# 6372  Female          68
# 6373  Female          69
# 6374  Female          68
# 6375  Female          68
# 6376    Male          64
#
# [6377 rows x 20 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
categorical_columns = df.select_dtypes(include=["object"]).columns

# %%
label_encoder = {}
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoder[col] = le

# %%
df
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0                23          84                     1                    0
# 1                19          64                     1                    2
# 2                24          98                     2                    2
# 3                29          89                     1                    2
# 4                19          92                     2                    2
# ...             ...         ...                   ...                  ...
# 6372             25          69                     0                    2
# 6373             23          76                     0                    2
# 6374             20          90                     2                    1
# 6375             10          86                     0                    0
# 6376             15          67                     2                    1
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7               73
# 1                              0            8               59
# 2                              1            7               91
# 3                              1            8               98
# 4                              1            6               65
# ...                          ...          ...              ...
# 6372                           0            7               76
# 6373                           0            8               81
# 6374                           1            6               65
# 6375                           1            6               91
# 6376                           1            9               94
#
#       Motivation_Level  Internet_Access  Tutoring_Sessions  Family_Income  \
# 0                    1                1                  0              1
# 1                    1                1                  2              2
# 2                    2                1                  2              2
# 3                    2                1                  1              2
# 4                    2                1                  3              2
# ...                ...              ...                ...            ...
# 6372                 2                1                  1              0
# 6373                 2                1                  3              1
# 6374                 1                1                  3              1
# 6375                 0                1                  2              1
# 6376                 2                1                  0              2
#
#       Teacher_Quality  School_Type  Peer_Influence  Physical_Activity  \
# 0                   2            1               2                  3
# 1                   2            1               0                  4
# 2                   2            1               1                  4
# 3                   2            1               0                  4
# 4                   0            1               1                  4
# ...               ...          ...             ...                ...
# 6372                2            1               2                  2
# 6373                0            1               2                  2
# 6374                2            1               0                  2
# 6375                2            0               2                  3
# 6376                2            1               2                  4
#
#       Learning_Disabilities  Parental_Education_Level  Distance_from_Home  \
# 0                         0                         1                   2
# 1                         0                         0                   1
# 2                         0                         2                   2
# 3                         0                         1                   1
# 4                         0                         0                   2
# ...                     ...                       ...                 ...
# 6372                      0                         1                   2
# 6373                      0                         1                   2
# 6374                      0                         2                   2
# 6375                      0                         1                   0
# 6376                      0                         2                   2
#
#       Gender  Exam_Score
# 0          1          67
# 1          0          61
# 2          1          74
# 3          1          71
# 4          0          70
# ...      ...         ...
# 6372       0          68
# 6373       0          69
# 6374       0          68
# 6375       0          68
# 6376       1          64
#
# [6377 rows x 20 columns]

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %%
X
# Out:
# array([[23, 84,  1, ...,  1,  2,  1],
#        [19, 64,  1, ...,  0,  1,  0],
#        [24, 98,  2, ...,  2,  2,  1],
#        ...,
#        [20, 90,  2, ...,  2,  2,  0],
#        [10, 86,  0, ...,  1,  0,  0],
#        [15, 67,  2, ...,  2,  2,  1]], dtype=int64)

# %%
y
# Out:
# array([67, 61, 74, ..., 68, 68, 64], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2,random_state=0)

# %%
import xgboost as xgb

# %%
regressor = xgb.XGBRegressor(tree_method = "gpu_hist",device = "cuda")
regressor.fit(X_train,y_train)
# Out:
# C:\Users\U-ser\Downloads\New folder\envs\ev_2\lib\site-packages\xgboost\core.py:158: UserWarning: [00:21:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\common\error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
first_row_features = X[0].reshape(1, -1)  # Access the first row and reshape it
actual_outcome = y[0]  # Access the first value in the target array
predicted_outcome = regressor.predict(first_row_features)
print("Actual outcome for the first row:", actual_outcome)
print("Predicted outcome for the first row:", predicted_outcome)
# Out:
# Actual outcome for the first row: 67
# Predicted outcome for the first row: [67.007065]

# %%
second_row_features = X[1].reshape(1, -1)  # Access the second row and reshape it
actual_outcome = y[1]  # Access the second value in the target array
predicted_outcome = regressor.predict(second_row_features)
print("Actual outcome for the second row:", actual_outcome)
print("Predicted outcome for the secomd row:", predicted_outcome)
# Out:
# Actual outcome for the second row: 61
# Predicted outcome for the secomd row: [60.97036]

# %%
third_row_features = X[2].reshape(1, -1)  # Access the third row and reshape it
actual_outcome = y[2]  # Access the third value in the target array
predicted_outcome = regressor.predict(third_row_features)
print("Actual outcome for the third row:", actual_outcome)
print("Predicted outcome for the third row:", predicted_outcome)
# Out:
# Actual outcome for the third row: 74
# Predicted outcome for the third row: [74.47783]

# %%
from sklearn.metrics import mean_absolute_error
y_pred = regressor.predict(X_test)
mae = mean_absolute_error(y_test,y_pred)
print("Mean absolue error is",mae)
# Out:
# Mean absolue error is 0.9997352313098489

# %%
from sklearn.metrics import mean_squared_error
y_pred = regressor.predict(X_test)
mse = mean_squared_error(y_test,y_pred)
print("Mean Squared Error is", mse)
# Out:
# Mean Squared Error is 5.269425203261636

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error is ", rmse)
# Out:
# Root Mean Squared Error is  2.2955228605399762

# %%
from sklearn.metrics import r2_score
y_pred = regressor.predict(X_test)
R_2 = r2_score(y_test,y_pred)
print("R squared score is",R_2)
# Out:
# R squared score is 0.6436640045393383
