# %%
import matplotlib.pyplot as plt

# Example data
categories = ['XGB', 'RandomForest', 'GradientBoosting', 'ExtraTrees','KNN','MultipleLinear','Lasso','LGBM','Ridge','SVR',
             'ElasticNet','DecisionTree','HUBER','BAYESIAN Ridge','MLP','NNR']
values = [0.9997352313098489,
          1.308307210031348,
          0.8250821073826347,
          1.0728683385579938,
          1.5286833855799373,
          1.028672176320524,
          1.1294980932293606,
          0.8329080514734177,
          1.0476964406067852,
         0.6486071348934603,
          1.1022840766815398,
          1.8197492163009403,
          1.038180523581539,
         1.0482645315512396,
          1.848931374882317,
         1.2000973112530844]

# Create the bar graph
plt.figure(figsize=(10, 6))  # Adjusted figure size for better visibility
plt.bar(categories, values)

# Add title and labels
plt.title("Mean Absolute Error")
plt.xlabel("Categories")
plt.ylabel("Values")

# Rotate category labels to avoid overlap
plt.xticks(rotation=90)  # Rotate labels to 90 degrees

# Show the plot
plt.tight_layout()  # Adjust layout to ensure everything fits
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data
categories = ['XGB', 'RandomForest', 'GradientBoosting', 'ExtraTrees','KNN','MultipleLinear','Lasso','LGBM','Ridge','SVR',
             'ElasticNet','DecisionTree','HUBER','BAYESIAN Ridge','MLP','NNR']
values = [5.269425203261636,
          5.92833855799373,
          4.37805571094985,
          5.008615830721003,
         7.085485893416928,
          4.91157729633586,
          5.172633482112928,
          4.452431282516631,
          5.268201105470662,
         4.490664280035396,
          5.444006542480604,
          13.195924764890282,
          5.214879334849432,
         5.2706716449914905,
          9.290415841431892,
         6.0167448172534455]

# Create the bar graph
plt.figure(figsize=(10, 6))  # Adjusted figure size for better visibility
plt.bar(categories, values)

# Add title and labels
plt.title("Mean Squared Error")
plt.xlabel("Categories")
plt.ylabel("Values")

# Rotate category labels to avoid overlap
plt.xticks(rotation=90)  # Rotate labels to 90 degrees

# Show the plot
plt.tight_layout()  # Adjust layout to ensure everything fits
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data
categories = ['XGB', 'RandomForest', 'GradientBoosting', 'ExtraTrees','KNN','MultipleLinear','Lasso','LGBM','Ridge','SVR',
             'ElasticNet','DecisionTree','HUBER','BAYESIAN Ridge','MLP','NNR']
values = [2.2955228605399762,
          2.4348179722504373,
          2.0923803934633516,
          2.2379937065865496,
         2.661857602017232,
          2.216207863973021,
          2.274342428508277,
          2.1100785015057215,
          2.2952562178263807,
          2.119118750810203,
          2.333239495311316,
          3.632619545849838,
          2.28361102967415,
         2.295794338565955,
          3.048018346636367,
         2.4529053828579377]

# Create the bar graph
plt.figure(figsize=(10, 6))  # Adjusted figure size for better visibility
plt.bar(categories, values)

# Add title and labels
plt.title("Root Mean Squared Error")
plt.xlabel("Categories")
plt.ylabel("Values")

# Rotate category labels to avoid overlap
plt.xticks(rotation=90)  # Rotate labels to 90 degrees

# Show the plot
plt.tight_layout()  # Adjust layout to ensure everything fits
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data
categories = ['XGB', 'RandomForest', 'GradientBoosting', 'ExtraTrees','KNN','MultipleLinear','Lasso','LGBM','Ridge','SVR',
             'ElasticNet','DecisionTree','HUBER','BAYESIAN Ridge','MLP','NNR']
values = [0.6436640045393383,
          0.5991060998108579,
          0.7039413636656395,
          0.6613007986496735,
          0.5208559621283924,
          0.6678628659367791,
          0.6502093814974412,
          0.6989118410308368,
          0.6634512032846468,
          0.7131226333920468,
          0.652220214357464,
          0.15700397303390545,
          0.6668575610492872,
          0.663293377665175,
          0.4064998260654248,
         0.6156319379806519]

# Create the bar graph
plt.figure(figsize=(10, 6))  # Adjusted figure size for better visibility
plt.bar(categories, values)

# Add title and labels
plt.title("R Squared")
plt.xlabel("Categories")
plt.ylabel("Values")

# Rotate category labels to avoid overlap
plt.xticks(rotation=90)  # Rotate labels to 90 degrees

# Show the plot
plt.tight_layout()  # Adjust layout to ensure everything fits
plt.show()
